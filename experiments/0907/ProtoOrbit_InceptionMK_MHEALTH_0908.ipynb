# %%
# !pip install ptflops
import os
import io
import math
import glob
import pandas as pd
import numpy as np
from collections import Counter
from pathlib import Path
from typing import Tuple
import time

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, silhouette_score, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_confusion_matrix
from ptflops import get_model_complexity_info

def split_sequences(features, labels, window_size, step):
    X_sequences, y_sequences = [], []

    for i in range(0, len(features) - window_size + 1, step):
        window_features = features[i:i + window_size]
        window_labels = labels[i:i + window_size]

        most_common_label = Counter(window_labels).most_common(1)[0][0]

        X_sequences.append(window_features)
        y_sequences.append(most_common_label)

    return np.array(X_sequences), np.array(y_sequences)

def load_mhealth_data(data_path, window_size=50, step=25):
    """
    Load mHealth dataset for PyTorch

    Args:
        data_path (str): Path to mHealth dataset folder
        window_size (int): Window size for sequences
        step (int): Step size for overlapping windows

    Returns:
        tuple: (X_windowed, y_sequences, activity_labels, num_classes)
    """
    print("Loading mHealth dataset...")

    # Find all log files in the folder
    log_files = glob.glob(os.path.join(data_path, "*.log"))

    if not log_files:
        raise FileNotFoundError(f"No log files found in {data_path}")

    print(f"Found {len(log_files)} log files")

    # Process each file and combine data
    all_data = []

    for log_file in log_files:
        print(f"Processing {os.path.basename(log_file)}")
        try:
            data = pd.read_csv(log_file, header=None, sep='\t')
            all_data.append(data)
        except Exception as e:
            print(f"Error reading {log_file}: {e}")
            continue

    if not all_data:
        raise ValueError("No valid data files found")

    # Combine all data
    combined_data = pd.concat(all_data, ignore_index=True)
    print(f"Combined data shape: {combined_data.shape}")

    # Extract features and labels
    # The last column (index 23) is the activity label
    features = combined_data.iloc[:, :-1].values  # 23 sensor features
    labels = combined_data.iloc[:, -1].values.astype(int)

    # Filter out records with activity label 0 (no activity)
    mask = labels != 0
    features = features[mask]
    labels = labels[mask]

    # Shift class labels down by 1 to start from 0
    labels = labels - 1

    print(f"Features shape after filtering: {features.shape}")
    print(f"Label distribution: {Counter(labels)}")

    # Create sequences
    X_sequences, y_sequences = split_sequences(features, labels, window_size, step)

    # Get class information
    unique_labels = np.unique(y_sequences)
    num_classes = len(unique_labels)

    activity_labels = [
        "Standing still", "Sitting and relaxing", "Lying down", "Walking",
        "Climbing stairs", "Waist bends forward", "Frontal elevation of arms",
        "Knees bending (crouching)", "Cycling", "Jogging", "Running", "Jump front & back"
    ]

    # Adjust to the number of features, time steps format (N, F, T)
    X_windowed = np.transpose(X_sequences, (0, 2, 1))  # (N, F, T)

    print(f"mHealth - Windowed data shape (N, F, T): {X_windowed.shape}")
    print(f"mHealth - Number of classes: {num_classes}")
    print(f"mHealth - Activities present: {[activity_labels[i] for i in unique_labels]}")

    return X_windowed, y_sequences, activity_labels, num_classes

def _batched_rotation_matrix(angles):
    """Create rotation matrices for random rotations (for data augmentation)"""
    B = angles.shape[0]
    rx, ry, rz = angles[:, 0], angles[:, 1], angles[:, 2]

    cx, sx = torch.cos(rx), torch.sin(rx)
    cy, sy = torch.cos(ry), torch.sin(ry)
    cz, sz = torch.cos(rz), torch.sin(rz)

    Rx = torch.zeros(B, 3, 3, device=angles.device, dtype=angles.dtype)
    Rx[:, 0, 0] = 1.
    Rx[:, 1, 1] = cx; Rx[:, 1, 2] = -sx
    Rx[:, 2, 1] = sx; Rx[:, 2, 2] = cx

    Ry = torch.zeros(B, 3, 3, device=angles.device, dtype=angles.dtype)
    Ry[:, 0, 0] = cy;  Ry[:, 0, 2] = sy
    Ry[:, 1, 1] = 1.
    Ry[:, 2, 0] = -sy; Ry[:, 2, 2] = cy

    Rz = torch.zeros(B, 3, 3, device=angles.device, dtype=angles.dtype)
    Rz[:, 0, 0] = cz; Rz[:, 0, 1] = -sz
    Rz[:, 1, 0] = sz; Rz[:, 1, 1] = cz
    Rz[:, 2, 2] = 1.

    R = Rz @ Ry @ Rx
    return R

def apply_random_rotation_subset(x, max_deg=20.0, rotation_channels=None):
    """Apply rotation to a subset of channels (e.g., accelerometer channels)"""
    B, T, C = x.shape

    if rotation_channels is None:
        # For mHealth, assume first 9 channels are IMU data (3 acc + 3 gyro + 3 mag for each sensor)
        # We'll rotate the first 3 channels (first accelerometer)
        rotation_channels = [0, 1, 2]

    max_rad = max_deg * math.pi / 180.0
    angles = (torch.rand(B, 3, device=x.device, dtype=x.dtype) * 2 - 1) * max_rad
    R = _batched_rotation_matrix(angles)

    x_rot = x.clone()
    if len(rotation_channels) >= 3:
        # Extract the 3D channels to rotate
        x_3d = x[:, :, rotation_channels[:3]]  # Take first 3 channels
        x_flat = x_3d.view(B*T, 3)
        R_expanded = R.repeat_interleave(T, dim=0)
        x_rot_flat = (R_expanded @ x_flat.unsqueeze(-1)).squeeze(-1)
        x_rot_3d = x_rot_flat.view(B, T, 3)
        x_rot[:, :, rotation_channels[:3]] = x_rot_3d

    return x_rot

def make_rotation_class(x, num_rotations=4, rotation_channels=None):
    """Create rotation classification task for SSL"""
    device = x.device
    B, T, C = x.shape

    if rotation_channels is None:
        rotation_channels = [0, 1, 2]  # First 3 channels

    angles_deg = torch.tensor([0., 90., 180., 270.], device=device, dtype=x.dtype)
    labels = torch.randint(0, len(angles_deg), (B,), device=device, dtype=torch.long)
    rad = angles_deg[labels] * math.pi / 180.0

    angles = torch.stack([torch.zeros_like(rad), torch.zeros_like(rad), rad], dim=1)
    R = _batched_rotation_matrix(angles)

    x_rot = x.clone()
    if len(rotation_channels) >= 3:
        x_3d = x[:, :, rotation_channels[:3]]
        x_flat = x_3d.view(B*T, 3)
        R_expanded = R.repeat_interleave(T, dim=0)
        x_rot_flat = (R_expanded @ x_flat.unsqueeze(-1)).squeeze(-1)
        x_rot_3d = x_rot_flat.view(B, T, 3)
        x_rot[:, :, rotation_channels[:3]] = x_rot_3d

    return x_rot, labels

class DSConv1D(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, use_residual=True):
        super().__init__()
        self.depthwise = nn.Conv1d(in_channels, in_channels, kernel_size=kernel_size,
                                   padding=kernel_size // 2, groups=in_channels, bias=False)
        self.pointwise = nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False)
        self.bn = nn.BatchNorm1d(out_channels)
        self.act = nn.LeakyReLU(negative_slope=0.1, inplace=True)

        self.use_residual = use_residual and (in_channels == out_channels)
        if use_residual and in_channels != out_channels:
            self.residual_proj = nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False),
                nn.BatchNorm1d(out_channels)
            )
        else:
            self.residual_proj = None

    def forward(self, x):
        identity = x
        out = self.depthwise(x)
        out = self.pointwise(out)
        out = self.bn(out)

        if self.use_residual:
            if self.residual_proj is not None:
                identity = self.residual_proj(identity)
            out = out + identity

        out = self.act(out)
        return out

class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.branch1 = nn.Sequential(
            nn.MaxPool1d(kernel_size=3, stride=1, padding=1),
            DSConv1D(in_channels, out_channels, kernel_size=1, use_residual=False)
        )
        self.branch2 = DSConv1D(in_channels, out_channels, kernel_size=1, use_residual=False)
        self.branch3 = DSConv1D(in_channels, out_channels, kernel_size=3, use_residual=False)
        self.branch4 = DSConv1D(in_channels, out_channels, kernel_size=5, use_residual=False)

        total_out_channels = out_channels * 4
        if in_channels != total_out_channels:
            self.residual_proj = nn.Sequential(
                nn.Conv1d(in_channels, total_out_channels, kernel_size=1, bias=False),
                nn.BatchNorm1d(total_out_channels)
            )
        else:
            self.residual_proj = None

        self.relu = nn.LeakyReLU(negative_slope=0.1, inplace=True)

    def forward(self, x):
        identity = x
        out = torch.cat([
            self.branch1(x), self.branch2(x),
            self.branch3(x), self.branch4(x)
        ], dim=1)

        if self.residual_proj is not None:
            identity = self.residual_proj(identity)
        out = out + identity

        return self.relu(out)

class MultiKernelBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.branch1 = DSConv1D(in_channels, out_channels, kernel_size=1, use_residual=False)
        self.branch2 = DSConv1D(in_channels, out_channels, kernel_size=3, use_residual=False)
        self.branch3 = DSConv1D(in_channels, out_channels, kernel_size=5, use_residual=False)
        self.branch4 = DSConv1D(in_channels, out_channels, kernel_size=7, use_residual=False)

        total_out_channels = out_channels * 4
        if in_channels != total_out_channels:
            self.residual_proj = nn.Sequential(
                nn.Conv1d(in_channels, total_out_channels, kernel_size=1, bias=False),
                nn.BatchNorm1d(total_out_channels)
            )
        else:
            self.residual_proj = None

        self.relu = nn.LeakyReLU(negative_slope=0.1, inplace=True)

    def forward(self, x):
        identity = x
        out = torch.cat([
            self.branch1(x), self.branch2(x),
            self.branch3(x), self.branch4(x)
        ], dim=1)

        if self.residual_proj is not None:
            identity = self.residual_proj(identity)
        out = out + identity

        return self.relu(out)

class FeatureAdapter(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.gamma = nn.Parameter(torch.ones(1, dim))
        self.beta = nn.Parameter(torch.zeros(1, dim))

    def forward(self, z):
        return z * self.gamma + self.beta

class InceptionMK(nn.Module):
    def __init__(self, input_channels=23, stem_out=64, block_out=32,
                 embedding_dim=128, num_classes=12, num_rotations=4):
        super().__init__()

        self.stem = nn.Sequential(
            nn.Conv1d(input_channels, stem_out, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm1d(stem_out),
            nn.LeakyReLU(negative_slope=0.1, inplace=True)
        )

        self.stem_residual = DSConv1D(stem_out, stem_out, kernel_size=3, use_residual=True)
        self.inception = InceptionBlock(stem_out, block_out)
        self.mk_block = MultiKernelBlock(block_out * 4, block_out)

        mk_out_channels = block_out * 4
        self.inter_residual = DSConv1D(mk_out_channels, mk_out_channels, kernel_size=3, use_residual=True)

        # Adjusted for mHealth sequence length (50)
        self.time_reduce = nn.Sequential(
            nn.Conv1d(mk_out_channels, mk_out_channels, kernel_size=5, stride=5, padding=0),
            nn.BatchNorm1d(mk_out_channels),
            nn.LeakyReLU(negative_slope=0.1, inplace=True)
        )

        # Adjusted flattened size for mHealth (50/5 = 10)
        flattened_size = mk_out_channels * 10
        self.fc = nn.Sequential(
            nn.Linear(flattened_size, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout(0.1),
            nn.Linear(256, embedding_dim)
        )

        self.adapter = FeatureAdapter(embedding_dim)

        self.head_act = nn.Sequential(
            nn.LayerNorm(embedding_dim),
            nn.Linear(embedding_dim, 64),
            nn.BatchNorm1d(64),
            nn.LeakyReLU(negative_slope=0.1, inplace=True),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.LeakyReLU(negative_slope=0.1, inplace=True),
            nn.Dropout(0.1),
            nn.Linear(32, num_classes)
        )

        self.head_rot = nn.Sequential(
            nn.LayerNorm(embedding_dim),
            nn.Linear(embedding_dim, 32),
            nn.BatchNorm1d(32),
            nn.LeakyReLU(negative_slope=0.1, inplace=True),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.BatchNorm1d(16),
            nn.LeakyReLU(negative_slope=0.1, inplace=True),
            nn.Dropout(0.1),
            nn.Linear(16, num_rotations)
        )

        self.num_classes = num_classes
        self.embedding_dim = embedding_dim
        self.register_buffer("prototypes", torch.zeros(num_classes, embedding_dim))
        self.register_buffer("proto_counts", torch.zeros(num_classes))
        self.proto_m = 0.99

    def forward(self, x):
        x = x.transpose(1, 2)  # (B, F, T)

        x = self.stem(x)
        x = self.stem_residual(x)
        x = self.inception(x)
        x = self.mk_block(x)
        x = self.inter_residual(x)

        x = self.time_reduce(x)
        x = x.flatten(1)
        z = self.fc(x)
        z = self.adapter(z)

        logits_act = self.head_act(z)
        logits_rot = self.head_rot(z)

        return logits_act, logits_rot, z

    @torch.no_grad()
    def update_prototypes(self, z, y):
        if z.size(0) == 0:
            return

        z_n = F.normalize(z, dim=-1)
        unique_classes = y.unique()

        for c in unique_classes:
            mask = (y == c)
            if mask.any():
                z_class = z_n[mask].mean(dim=0)
                count = self.proto_counts[c]

                if count == 0:
                    self.prototypes[c] = z_class
                    self.proto_counts[c] = 1
                else:
                    self.prototypes[c] = self.proto_m * self.prototypes[c] + (1 - self.proto_m) * z_class
                    self.proto_counts[c] += 1

def rotation_consistency_loss(model, x, K=2, max_deg=15.0, temperature=1.0):
    with torch.no_grad():
        base_logits, _, _ = model.forward(x)
        base_logits = base_logits / temperature
        p_base = F.softmax(base_logits, dim=-1)

    kl_losses = []
    for _ in range(K):
        xr = apply_random_rotation_subset(x, max_deg=max_deg)
        logits_r, _, _ = model.forward(xr)
        p_r = F.log_softmax(logits_r / temperature, dim=-1)
        kl = F.kl_div(p_r, p_base, reduction='batchmean', log_target=False)
        kl_losses.append(kl)

    return sum(kl_losses) / len(kl_losses)

def proto_orbit_loss(model, x, y, K=2, max_deg=20.0, temperature=0.2):
    proto = model.prototypes.detach()
    proto_n = F.normalize(proto, dim=-1)

    if torch.all(proto == 0):
        dummy_loss = torch.zeros(1, device=x.device, requires_grad=True)
        return dummy_loss.sum()

    losses = []
    for _ in range(K):
        xr = apply_random_rotation_subset(x, max_deg=max_deg)
        _, _, z_r = model(xr)
        z_r = F.normalize(z_r, dim=-1)
        logits = (z_r @ proto_n.t()) / temperature
        loss = F.cross_entropy(logits, y)
        losses.append(loss)

    return sum(losses) / len(losses)

def _entropy(p):
    return -(p * (p.clamp_min(1e-8).log())).sum(dim=-1)

def roco_tta_predict(model, x, steps=10, K=6, lr=2e-3, max_deg=40.0, temperature=0.2, weight_cons=2.0):
    was_training = model.training
    model.eval()

    original_state = {}
    for name, param in model.named_parameters():
        original_state[name] = param.data.clone()

    bn_backup = {}
    for name, module in model.named_modules():
        if isinstance(module, nn.BatchNorm1d):
            bn_backup[name] = {
                'running_mean': module.running_mean.clone(),
                'running_var': module.running_var.clone(),
                'num_batches_tracked': module.num_batches_tracked.clone() if module.num_batches_tracked is not None else None
            }
    for name, param in model.named_parameters():
        param.requires_grad_(False)

    tta_params = []
    for param in model.adapter.parameters():
        param.requires_grad_(True)
        tta_params.append(param)

    for name, module in model.named_modules():
        if isinstance(module, nn.BatchNorm1d):
            module.eval()
            if module.affine:
                module.weight.requires_grad_(True)
                module.bias.requires_grad_(True)
                tta_params.append(module.weight)
                tta_params.append(module.bias)

    if not tta_params:
        return model(x)[0].softmax(dim=-1)

    opt = torch.optim.AdamW(tta_params, lr=lr, weight_decay=1e-5)

    for step in range(steps):
        opt.zero_grad()

        lo0, _, _ = model.forward(x)
        p0 = F.softmax(lo0 / temperature, dim=-1)
        ent = _entropy(p0).mean()

        kl = 0.0
        for _k in range(K):
            xr = apply_random_rotation_subset(x, max_deg=max_deg)
            lor, _, _ = model.forward(xr)
            pr = F.log_softmax(lor / temperature, dim=-1)
            kl += F.kl_div(pr, p0.detach(), reduction='batchmean', log_target=False)
        kl = kl / K

        loss = ent + weight_cons * kl
        loss.backward()
        torch.nn.utils.clip_grad_norm_(tta_params, max_norm=1.0)
        opt.step()

    probs = []
    with torch.no_grad():
        for _k in range(K * 2):
            xr = apply_random_rotation_subset(x, max_deg=max_deg * 0.5)
            lor, _, _ = model.forward(xr)
            probs.append(F.softmax(lor, dim=-1))
    probs = torch.stack(probs, dim=0).mean(dim=0)

    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data.copy_(original_state[name])

    for name, module in model.named_modules():
        if isinstance(module, nn.BatchNorm1d) and name in bn_backup:
            module.running_mean.copy_(bn_backup[name]['running_mean'])
            module.running_var.copy_(bn_backup[name]['running_var'])
            if module.num_batches_tracked is not None:
                module.num_batches_tracked.copy_(bn_backup[name]['num_batches_tracked'])

    for param in model.parameters():
        param.requires_grad_(True)

    if was_training:
        model.train()
    else:
        model.eval()

    return probs

class MHealthDataset(Dataset):
    def __init__(self, X, y, scaler: StandardScaler=None, train: bool=True,
                 rot_ssl: bool=True, num_rotations: int=4, p_rotate_ssl: float=0.5):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        self.train = train
        self.rot_ssl = rot_ssl
        self.num_rot = num_rotations
        self.p_rotate_ssl = p_rotate_ssl

        self.scaler = scaler
        if self.scaler is not None:
            N, F, T = self.X.shape
            X2 = self.X.reshape(-1, F)
            X2 = self.scaler.transform(X2)
            self.X = X2.reshape(N, F, T)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).transpose(0, 1)  # (T, F)
        y = torch.tensor(self.y[idx], dtype=torch.long)

        rot_label = torch.tensor(0, dtype=torch.long)
        x_ssl = x.clone()
        apply_rot = False

        if self.train and self.rot_ssl and np.random.rand() < self.p_rotate_ssl:
            apply_rot = True
            x_ssl_batch, rot_label_batch = make_rotation_class(x.unsqueeze(0), num_rotations=self.num_rot)
            x_ssl = x_ssl_batch.squeeze(0)
            rot_label = rot_label_batch.squeeze(0) if rot_label_batch.dim() > 0 else rot_label_batch

        return x_ssl, y, rot_label, torch.tensor(apply_rot, dtype=torch.bool)

def train_one_epoch(model, loader, optimizer, device,
                    lambda_rot=0.5, lambda_rc=0.1,
                    lambda_orbit=0.3, orbit_K=2, orbit_tau=0.2, orbit_max_deg=20.0):
    model.train()
    total_loss = total_act = total_rot = total_orbit = total_rc = 0.0
    correct = total = 0

    for batch_idx, (xb, yb, rb, msk) in enumerate(loader):
        try:
            xb, yb, rb, msk = xb.to(device), yb.to(device), rb.to(device), msk.to(device)

            lo_act, lo_rot, z = model(xb)
            loss_act = F.cross_entropy(lo_act, yb)

            if msk.any():
                loss_rot = F.cross_entropy(lo_rot[msk], rb[msk])
            else:
                loss_rot = torch.zeros_like(loss_act)

            with torch.no_grad():
                model.update_prototypes(z, yb)

            if lambda_orbit > 0.0 and model.proto_counts.sum() > 0:
                loss_orbit = proto_orbit_loss(model, xb, yb, K=orbit_K,
                                            max_deg=orbit_max_deg, temperature=orbit_tau)
            else:
                loss_orbit = torch.zeros_like(loss_act)

            loss_rc_val = torch.zeros_like(loss_act)
            if lambda_rc > 0:
                loss_rc_val = rotation_consistency_loss(model, xb, K=2, max_deg=15.0)

            loss = loss_act + lambda_rot * loss_rot + lambda_orbit * loss_orbit + lambda_rc * loss_rc_val

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            bs = xb.size(0)
            total += bs
            correct += (lo_act.argmax(dim=1) == yb).sum().item()
            total_loss += float(loss.item()) * bs
            total_act += float(loss_act.item()) * bs
            total_rot += float(loss_rot.item()) * bs
            total_orbit += float(loss_orbit.item()) * bs
            total_rc += float(loss_rc_val.item()) * bs

        except Exception as e:
            print(f"Error in batch {batch_idx}: {e}")
            continue

    acc = correct / total
    return (total_loss/total, total_act/total, total_rot/total,
            total_orbit/total, total_rc/total, acc)

@torch.no_grad()
def evaluate(model, loader, device, lambda_rot=0.5, lambda_orbit=0.3, lambda_rc=0.1, use_tta=False,
             tta_steps=10, tta_K=6, tta_lr=2e-3, tta_max_deg=40.0, tta_temperature=0.2, tta_weight_cons=2.0):
    model.eval()
    y_true, y_pred, embeddings = [], [], []
    correct = total = 0
    val_total_loss = val_act = val_rot = val_orbit = val_rc = 0.0

    for xb, yb, rb, msk in loader:
        xb, yb, rb, msk = xb.to(device), yb.to(device), rb.to(device), msk.to(device)
        y_true.append(yb.cpu().numpy())
        total += xb.size(0)

        if use_tta:
            with torch.enable_grad():
                probs = roco_tta_predict(model, xb, steps=tta_steps, K=tta_K, lr=tta_lr,
                                       max_deg=tta_max_deg, temperature=tta_temperature, weight_cons=tta_weight_cons)
            pred = probs.argmax(dim=-1).cpu().numpy()
            lo, lo_rot_val, z = model(xb)
            embeddings.append(z.cpu().numpy())
        else:
            lo, lo_rot_val, z = model(xb)
            pred = lo.argmax(dim=-1).cpu().numpy()
            embeddings.append(z.cpu().numpy())

        loss_act = F.cross_entropy(lo, yb)
        if msk.any():
            loss_rot = F.cross_entropy(lo_rot_val[msk], rb[msk])
        else:
            loss_rot = torch.zeros_like(loss_act)

        if lambda_orbit > 0.0 and model.proto_counts.sum() > 0:
            loss_orbit = proto_orbit_loss(model, xb, yb, K=2, max_deg=20.0, temperature=0.2)
        else:
            loss_orbit = torch.zeros_like(loss_act)

        loss_rc_val = torch.zeros_like(loss_act)
        if lambda_rc > 0:
            loss_rc_val = rotation_consistency_loss(model, xb, K=2, max_deg=15.0)

        bs = xb.size(0)
        val_act += float(loss_act.item()) * bs
        val_rot += float(loss_rot.item()) * bs
        val_orbit += float(loss_orbit.item()) * bs
        val_rc += float(loss_rc_val.item()) * bs
        val_total_loss += float((loss_act + lambda_rot * loss_rot + lambda_orbit * loss_orbit + lambda_rc * loss_rc_val).item()) * bs

        y_pred.append(pred)
        correct += (torch.from_numpy(pred) == yb.cpu()).sum().item()

    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)
    embeddings = np.concatenate(embeddings)

    acc = correct / total
    f1 = f1_score(y_true, y_pred, average="macro")
    precision = precision_score(y_true, y_pred, average="macro")
    recall = recall_score(y_true, y_pred, average="macro")

    return (acc, f1, precision, recall, y_true, y_pred, embeddings,
            val_total_loss/total, val_act/total, val_rot/total, val_orbit/total, val_rc/total)

def plot_confusion_matrix_mlxtend(y_true, y_pred, class_names):
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_true, y_pred)

    fig, ax = plot_confusion_matrix(conf_mat=cm,
                                    class_names=class_names,
                                    show_absolute=True,
                                    show_normed=True,
                                    colorbar=True)
    plt.title('Confusion Matrix')
    plt.tight_layout()
    return fig

def plot_tsne(embeddings, y_true, class_names):
    tsne = TSNE(n_components=2, random_state=42, perplexity=30)
    embeddings_2d = tsne.fit_transform(embeddings)

    plt.figure(figsize=(12, 10))
    colors = plt.cm.tab10(np.linspace(0, 1, len(class_names)))

    for i, class_name in enumerate(class_names):
        mask = y_true == i
        if mask.any():
            plt.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1],
                       label=class_name, alpha=0.6, color=colors[i], s=30)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.title('t-SNE Visualization of Embeddings')
    plt.xlabel('t-SNE 1')
    plt.ylabel('t-SNE 2')
    plt.tight_layout()
    return plt.gcf()

def main():
    print("MHEALTH Activity Recognition with InceptionMK")
    print("="*60)

    # Update this path to your mHealth dataset
    dataset_path = "/content/"

    try:
        X_full, y_full, class_names, num_classes = load_mhealth_data(
            dataset_path, window_size=50, step=25
        )
    except Exception as e:
        print(f"Failed to load mHealth data: {e}")
        return

    if X_full is None:
        print("Failed to load mHealth data")
        return

    X_train, X_test, y_train, y_test = train_test_split(
        X_full, y_full, test_size=0.3, random_state=42, stratify=y_full
    )

    scaler = StandardScaler()
    N_train, F, T = X_train.shape
    X_train_reshaped = X_train.reshape(-1, F)
    scaler.fit(X_train_reshaped)

    X_train_scaled = scaler.transform(X_train_reshaped).reshape(N_train, F, T)
    N_test = X_test.shape[0]
    X_test_reshaped = X_test.reshape(-1, F)
    X_test_scaled = scaler.transform(X_test_reshaped).reshape(N_test, F, T)

    train_ds = MHealthDataset(X_train_scaled, y_train, train=True,
                            rot_ssl=True, num_rotations=4, p_rotate_ssl=0.7)
    test_ds = MHealthDataset(X_test_scaled, y_test, train=False,
                           rot_ssl=False, num_rotations=4, p_rotate_ssl=0.0)

    train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, num_workers=0, drop_last=False)
    test_loader = DataLoader(test_ds, batch_size=64, shuffle=False, num_workers=0, drop_last=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    model = InceptionMK(input_channels=23, stem_out=64, block_out=32,
                        embedding_dim=128, num_classes=num_classes, num_rotations=4).to(device)

    try:
        flops, params = get_model_complexity_info(model, (50, 23), as_strings=True, print_per_layer_stat=False)
        print(f"Model FLOPs: {flops}")
        print(f"Model Params: {params}")
    except Exception as e:
        print(f"Could not compute model complexity: {e}")

    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-5)

    best = {"acc": 0.0, "f1": 0.0, "state": None}
    epochs = 200
    patience = 50
    patience_counter = 0

    lambda_rot, lambda_orbit, lambda_rc = 0.3, 0.2, 0.2

    history = {
        'train_total_loss': [], 'train_act_loss': [], 'train_rot_loss': [],
        'train_orbit_loss': [], 'train_rc_loss': [], 'train_acc': [],
        'val_total_loss': [], 'val_act_loss': [], 'val_rot_loss': [],
        'val_orbit_loss': [], 'val_rc_loss': [], 'val_acc': [], 'val_f1': []
    }

    print("Starting training...")
    start_time = time.time()

    for ep in range(1, epochs+1):
        tr_total_loss, tr_act, tr_rot, tr_orb, tr_rc, tr_acc = train_one_epoch(
            model, train_loader, optimizer, device,
            lambda_rot=lambda_rot, lambda_rc=lambda_rc, lambda_orbit=lambda_orbit,
            orbit_K=2, orbit_tau=0.3, orbit_max_deg=15.0
        )

        results = evaluate(model, test_loader, device, lambda_rot, lambda_orbit, lambda_rc, use_tta=False)
        acc, f1, precision, recall, y_true, y_pred, embeddings, val_total_loss, val_act, val_rot, val_orbit, val_rc = results

        scheduler.step()

        history['train_total_loss'].append(tr_total_loss)
        history['train_act_loss'].append(tr_act)
        history['train_rot_loss'].append(tr_rot)
        history['train_orbit_loss'].append(tr_orb)
        history['train_rc_loss'].append(tr_rc)
        history['train_acc'].append(tr_acc)
        history['val_total_loss'].append(val_total_loss)
        history['val_act_loss'].append(val_act)
        history['val_rot_loss'].append(val_rot)
        history['val_orbit_loss'].append(val_orbit)
        history['val_rc_loss'].append(val_rc)
        history['val_acc'].append(acc)
        history['val_f1'].append(f1)

        print(f"[Epoch {ep:02d}] train_loss={tr_total_loss:.4f} (act={tr_act:.4f}, rot={tr_rot:.4f}, orbit={tr_orb:.4f}, rc={tr_rc:.4f}) train_acc={tr_acc:.4f}")
        print(f"          val_loss={val_total_loss:.4f} (act={val_act:.4f}, rot={val_rot:.4f}, orbit={val_orbit:.4f}, rc={val_rc:.4f}) val_acc={acc:.4f} val_f1={f1:.4f}")

        if f1 > best["f1"]:
            best.update({"acc": acc, "f1": f1, "state": {k: v.cpu() for k, v in model.state_dict().items()}})
            patience_counter = 0
            torch.save(model.state_dict(), "best_mhealth_model.pth")
            print(f"  ★ New best F1: {f1:.4f} - Model saved")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {ep}")
                break

    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f} seconds")

    if best["state"] is not None:
        model.load_state_dict({k: v.to(device) for k, v in best["state"].items()})

    tta_steps = 30
    tta_K = 4
    tta_lr = 2e-3
    tta_max_deg = 10.0
    tta_temperature = 0.5
    tta_weight_cons = 2.0

    for test_type in ["NO ROCO_TTA", "ROCO_TTA"]:
        print("###" * 10)
        print(test_type)
        print("###" * 10)

        use_roco_tta = (test_type == "ROCO_TTA")

        print("Final evaluation...")
        start_time = time.time()
        results_final = evaluate(model, test_loader, device, lambda_rot, lambda_orbit, lambda_rc,
                                use_tta=use_roco_tta, tta_steps=tta_steps, tta_K=tta_K, tta_lr=tta_lr,
                                tta_max_deg=tta_max_deg, tta_temperature=tta_temperature, tta_weight_cons=tta_weight_cons)
        acc_final, f1_final, precision_final, recall_final, y_true_final, y_pred_final, embeddings_final = results_final[:7]
        inference_time = time.time() - start_time

        try:
            silhouette = silhouette_score(embeddings_final, y_true_final)
        except:
            silhouette = 0.0

        print("\n=== FINAL RESULTS ===")
        print(f"Accuracy: {acc_final:.4f}")
        print(f"F1 Score: {f1_final:.4f}")
        print(f"Precision: {precision_final:.4f}")
        print(f"Recall: {recall_final:.4f}")
        print(f"Sensitivity: {recall_final:.4f}")
        print(f"Silhouette Score: {silhouette:.4f}")
        print(f"Training Time: {training_time:.2f}s")
        print(f"Inference Time: {inference_time:.2f}s")

        print("\nClass-wise F1 Scores:")
        class_f1 = f1_score(y_true_final, y_pred_final, average=None)
        available_classes = np.unique(y_true_final)
        for i in available_classes:
            if i < len(class_names):
                print(f"{class_names[i]}: {class_f1[i]:.4f}")

        print("\nGenerating visualizations...")

        try:
            available_class_names = [class_names[i] for i in available_classes if i < len(class_names)]
            cm_fig = plot_confusion_matrix_mlxtend(y_true_final, y_pred_final, available_class_names)
            plt.show()
        except Exception as e:
            print(f"Could not generate confusion matrix: {e}")

        try:
            available_class_names = [class_names[i] for i in available_classes if i < len(class_names)]
            tsne_fig = plot_tsne(embeddings_final, y_true_final, available_class_names)
            plt.show()
        except Exception as e:
            print(f"Could not generate t-SNE plot: {e}")

        print("\nEvaluation complete!")
        print()

if __name__ == "__main__":
    main()
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from ptflops) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->ptflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->ptflops) (3.0.2)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: ptflops
# Successfully installed ptflops-0.7.5
# MHEALTH Activity Recognition with InceptionMK
# ============================================================
# Loading mHealth dataset...
# Found 10 log files
# Processing mHealth_subject1.log
# Processing mHealth_subject2.log
# Processing mHealth_subject4.log
# Processing mHealth_subject9.log
# Processing mHealth_subject7.log
# Processing mHealth_subject5.log
# Processing mHealth_subject8.log
# Processing mHealth_subject6.log
# Processing mHealth_subject3.log
# Processing mHealth_subject10.log
# Combined data shape: (1215745, 24)
# Features shape after filtering: (343195, 23)
# Label distribution: Counter({np.int64(0): 30720, np.int64(1): 30720, np.int64(2): 30720, np.int64(3): 30720, np.int64(8): 30720, np.int64(9): 30720, np.int64(10): 30720, np.int64(4): 30720, np.int64(6): 29441, np.int64(7): 29337, np.int64(5): 28315, np.int64(11): 10342})
# mHealth - Windowed data shape (N, F, T): (13726, 23, 50)
# mHealth - Number of classes: 12
# mHealth - Activities present: ['Standing still', 'Sitting and relaxing', 'Lying down', 'Walking', 'Climbing stairs', 'Waist bends forward', 'Frontal elevation of arms', 'Knees bending (crouching)', 'Cycling', 'Jogging', 'Running', 'Jump front & back']
# Using device: cuda
# Model FLOPs: 4.36 MMac
# Model Params: 522.37 k
# Starting training...
# [Epoch 01] train_loss=1.5497 (act=0.9873, rot=1.1089, orbit=1.0639, rc=0.0845) train_acc=0.7962
#           val_loss=0.3877 (act=0.3226, rot=0.0000, orbit=0.3234, rc=0.0020) val_acc=0.9424 val_f1=0.9117
#   ★ New best F1: 0.9117 - Model saved
# [Epoch 02] train_loss=0.5754 (act=0.2641, rot=0.6196, orbit=0.5219, rc=0.1052) train_acc=0.9610
#           val_loss=0.2735 (act=0.2236, rot=0.0000, orbit=0.2460, rc=0.0037) val_acc=0.9405 val_f1=0.9401
#   ★ New best F1: 0.9401 - Model saved
# [Epoch 03] train_loss=0.3647 (act=0.1393, rot=0.4002, orbit=0.4436, rc=0.0830) train_acc=0.9751
#           val_loss=0.1038 (act=0.0743, rot=0.0000, orbit=0.1449, rc=0.0023) val_acc=0.9832 val_f1=0.9828
#   ★ New best F1: 0.9828 - Model saved
# [Epoch 04] train_loss=0.3005 (act=0.1080, rot=0.3155, orbit=0.4209, rc=0.0683) train_acc=0.9779
#           val_loss=0.1254 (act=0.0916, rot=0.0000, orbit=0.1632, rc=0.0059) val_acc=0.9796 val_f1=0.9798
# [Epoch 05] train_loss=0.2581 (act=0.0816, rot=0.2777, orbit=0.4035, rc=0.0621) train_acc=0.9816
#           val_loss=0.1254 (act=0.0953, rot=0.0000, orbit=0.1473, rc=0.0032) val_acc=0.9709 val_f1=0.9720
# [Epoch 06] train_loss=0.2241 (act=0.0637, rot=0.2416, orbit=0.3888, rc=0.0508) train_acc=0.9851
#           val_loss=0.0819 (act=0.0580, rot=0.0000, orbit=0.1167, rc=0.0024) val_acc=0.9879 val_f1=0.9882
#   ★ New best F1: 0.9882 - Model saved
# [Epoch 07] train_loss=0.2063 (act=0.0568, rot=0.2177, orbit=0.3796, rc=0.0413) train_acc=0.9873
#           val_loss=0.0901 (act=0.0649, rot=0.0000, orbit=0.1230, rc=0.0031) val_acc=0.9832 val_f1=0.9837
# [Epoch 08] train_loss=0.1903 (act=0.0428, rot=0.2202, orbit=0.3699, rc=0.0374) train_acc=0.9903
#           val_loss=0.0600 (act=0.0377, rot=0.0000, orbit=0.1090, rc=0.0023) val_acc=0.9881 val_f1=0.9885
#   ★ New best F1: 0.9885 - Model saved
# [Epoch 09] train_loss=0.1819 (act=0.0459, rot=0.1825, orbit=0.3715, rc=0.0347) train_acc=0.9891
#           val_loss=0.1162 (act=0.0895, rot=0.0000, orbit=0.1295, rc=0.0038) val_acc=0.9806 val_f1=0.9781
# [Epoch 10] train_loss=0.1695 (act=0.0399, rot=0.1691, orbit=0.3620, rc=0.0321) train_acc=0.9894
#           val_loss=0.0527 (act=0.0330, rot=0.0000, orbit=0.0950, rc=0.0033) val_acc=0.9917 val_f1=0.9914
#   ★ New best F1: 0.9914 - Model saved
# [Epoch 11] train_loss=0.1613 (act=0.0347, rot=0.1644, orbit=0.3570, rc=0.0293) train_acc=0.9906
#           val_loss=0.0748 (act=0.0502, rot=0.0000, orbit=0.1171, rc=0.0059) val_acc=0.9898 val_f1=0.9897
# [Epoch 12] train_loss=0.1611 (act=0.0378, rot=0.1597, orbit=0.3508, rc=0.0261) train_acc=0.9903
#           val_loss=0.0611 (act=0.0363, rot=0.0000, orbit=0.1200, rc=0.0040) val_acc=0.9927 val_f1=0.9928
#   ★ New best F1: 0.9928 - Model saved
# [Epoch 13] train_loss=0.1419 (act=0.0254, rot=0.1419, orbit=0.3462, rc=0.0238) train_acc=0.9929
#           val_loss=0.0762 (act=0.0551, rot=0.0000, orbit=0.1029, rc=0.0025) val_acc=0.9871 val_f1=0.9871
# [Epoch 14] train_loss=0.1424 (act=0.0250, rot=0.1478, orbit=0.3442, rc=0.0211) train_acc=0.9937
#           val_loss=0.0529 (act=0.0330, rot=0.0000, orbit=0.0960, rc=0.0036) val_acc=0.9927 val_f1=0.9928
#   ★ New best F1: 0.9928 - Model saved
# [Epoch 15] train_loss=0.1348 (act=0.0229, rot=0.1320, orbit=0.3410, rc=0.0206) train_acc=0.9944
#           val_loss=0.0732 (act=0.0508, rot=0.0000, orbit=0.1076, rc=0.0044) val_acc=0.9859 val_f1=0.9860
# [Epoch 16] train_loss=0.1356 (act=0.0256, rot=0.1323, orbit=0.3342, rc=0.0172) train_acc=0.9941
#           val_loss=0.0542 (act=0.0319, rot=0.0000, orbit=0.1064, rc=0.0050) val_acc=0.9942 val_f1=0.9942
#   ★ New best F1: 0.9942 - Model saved
# [Epoch 17] train_loss=0.1251 (act=0.0204, rot=0.1180, orbit=0.3296, rc=0.0165) train_acc=0.9947
#           val_loss=0.2146 (act=0.1757, rot=0.0000, orbit=0.1759, rc=0.0187) val_acc=0.9621 val_f1=0.9634
# [Epoch 18] train_loss=0.1325 (act=0.0264, rot=0.1143, orbit=0.3377, rc=0.0217) train_acc=0.9926
#           val_loss=0.0564 (act=0.0355, rot=0.0000, orbit=0.1028, rc=0.0016) val_acc=0.9917 val_f1=0.9920
# [Epoch 19] train_loss=0.1332 (act=0.0290, rot=0.1142, orbit=0.3306, rc=0.0193) train_acc=0.9920
#           val_loss=0.0817 (act=0.0600, rot=0.0000, orbit=0.1024, rc=0.0062) val_acc=0.9893 val_f1=0.9897
# [Epoch 20] train_loss=0.1099 (act=0.0138, rot=0.0967, orbit=0.3191, rc=0.0163) train_acc=0.9967
#           val_loss=0.0580 (act=0.0412, rot=0.0000, orbit=0.0836, rc=0.0004) val_acc=0.9932 val_f1=0.9930
# [Epoch 21] train_loss=0.1162 (act=0.0180, rot=0.1069, orbit=0.3178, rc=0.0128) train_acc=0.9961
#           val_loss=0.0365 (act=0.0210, rot=0.0000, orbit=0.0753, rc=0.0020) val_acc=0.9954 val_f1=0.9951
#   ★ New best F1: 0.9951 - Model saved
# [Epoch 22] train_loss=0.1185 (act=0.0196, rot=0.1063, orbit=0.3202, rc=0.0152) train_acc=0.9952
#           val_loss=0.0441 (act=0.0272, rot=0.0000, orbit=0.0826, rc=0.0021) val_acc=0.9949 val_f1=0.9951
# [Epoch 23] train_loss=0.1055 (act=0.0144, rot=0.0827, orbit=0.3159, rc=0.0153) train_acc=0.9964
#           val_loss=0.0502 (act=0.0338, rot=0.0000, orbit=0.0797, rc=0.0023) val_acc=0.9917 val_f1=0.9922
# [Epoch 24] train_loss=0.1074 (act=0.0147, rot=0.0946, orbit=0.3108, rc=0.0108) train_acc=0.9970
#           val_loss=0.0452 (act=0.0280, rot=0.0000, orbit=0.0821, rc=0.0041) val_acc=0.9947 val_f1=0.9946
# [Epoch 25] train_loss=0.0995 (act=0.0111, rot=0.0805, orbit=0.3086, rc=0.0127) train_acc=0.9971
#           val_loss=0.0536 (act=0.0358, rot=0.0000, orbit=0.0860, rc=0.0030) val_acc=0.9922 val_f1=0.9923
# [Epoch 26] train_loss=0.1038 (act=0.0143, rot=0.0848, orbit=0.3079, rc=0.0124) train_acc=0.9968
#           val_loss=0.0503 (act=0.0312, rot=0.0000, orbit=0.0875, rc=0.0081) val_acc=0.9934 val_f1=0.9935
# [Epoch 27] train_loss=0.1043 (act=0.0139, rot=0.0873, orbit=0.3077, rc=0.0132) train_acc=0.9964
#           val_loss=0.0942 (act=0.0737, rot=0.0000, orbit=0.0983, rc=0.0039) val_acc=0.9854 val_f1=0.9859
# [Epoch 28] train_loss=0.1072 (act=0.0174, rot=0.0858, orbit=0.3078, rc=0.0129) train_acc=0.9965
#           val_loss=0.0364 (act=0.0216, rot=0.0000, orbit=0.0713, rc=0.0030) val_acc=0.9956 val_f1=0.9956
#   ★ New best F1: 0.9956 - Model saved
# [Epoch 29] train_loss=0.1045 (act=0.0181, rot=0.0757, orbit=0.3082, rc=0.0101) train_acc=0.9955
#           val_loss=0.0443 (act=0.0277, rot=0.0000, orbit=0.0798, rc=0.0032) val_acc=0.9949 val_f1=0.9944
# [Epoch 30] train_loss=0.1048 (act=0.0173, rot=0.0797, orbit=0.3053, rc=0.0123) train_acc=0.9965
#           val_loss=0.0464 (act=0.0313, rot=0.0000, orbit=0.0744, rc=0.0011) val_acc=0.9925 val_f1=0.9928
# [Epoch 31] train_loss=0.1012 (act=0.0143, rot=0.0806, orbit=0.3013, rc=0.0124) train_acc=0.9965
#           val_loss=0.1306 (act=0.1019, rot=0.0000, orbit=0.1336, rc=0.0102) val_acc=0.9813 val_f1=0.9818
# [Epoch 32] train_loss=0.0946 (act=0.0124, rot=0.0670, orbit=0.2999, rc=0.0107) train_acc=0.9967
#           val_loss=0.0664 (act=0.0487, rot=0.0000, orbit=0.0848, rc=0.0039) val_acc=0.9893 val_f1=0.9892
# [Epoch 33] train_loss=0.0913 (act=0.0087, rot=0.0714, orbit=0.2976, rc=0.0085) train_acc=0.9981
#           val_loss=0.0664 (act=0.0483, rot=0.0000, orbit=0.0884, rc=0.0024) val_acc=0.9913 val_f1=0.9908
# [Epoch 34] train_loss=0.1006 (act=0.0195, rot=0.0635, orbit=0.3001, rc=0.0099) train_acc=0.9969
#           val_loss=0.0726 (act=0.0531, rot=0.0000, orbit=0.0899, rc=0.0075) val_acc=0.9910 val_f1=0.9911
# [Epoch 35] train_loss=0.0932 (act=0.0126, rot=0.0652, orbit=0.2967, rc=0.0083) train_acc=0.9973
#           val_loss=0.0755 (act=0.0582, rot=0.0000, orbit=0.0849, rc=0.0013) val_acc=0.9920 val_f1=0.9922
# [Epoch 36] train_loss=0.0964 (act=0.0146, rot=0.0685, orbit=0.2966, rc=0.0097) train_acc=0.9966
#           val_loss=0.0581 (act=0.0408, rot=0.0000, orbit=0.0852, rc=0.0014) val_acc=0.9930 val_f1=0.9928
# [Epoch 37] train_loss=0.0985 (act=0.0197, rot=0.0571, orbit=0.2981, rc=0.0104) train_acc=0.9951
#           val_loss=0.0531 (act=0.0351, rot=0.0000, orbit=0.0867, rc=0.0033) val_acc=0.9939 val_f1=0.9939
# [Epoch 38] train_loss=0.0809 (act=0.0052, rot=0.0569, orbit=0.2873, rc=0.0057) train_acc=0.9990
#           val_loss=0.0520 (act=0.0361, rot=0.0000, orbit=0.0783, rc=0.0014) val_acc=0.9932 val_f1=0.9926
# [Epoch 39] train_loss=0.0916 (act=0.0130, rot=0.0609, orbit=0.2933, rc=0.0081) train_acc=0.9972
#           val_loss=0.0978 (act=0.0764, rot=0.0000, orbit=0.1012, rc=0.0056) val_acc=0.9849 val_f1=0.9850
# [Epoch 40] train_loss=0.0932 (act=0.0159, rot=0.0536, orbit=0.2964, rc=0.0094) train_acc=0.9960
#           val_loss=0.0533 (act=0.0378, rot=0.0000, orbit=0.0770, rc=0.0009) val_acc=0.9934 val_f1=0.9935
# [Epoch 41] train_loss=0.0808 (act=0.0063, rot=0.0518, orbit=0.2884, rc=0.0064) train_acc=0.9986
#           val_loss=0.0569 (act=0.0423, rot=0.0000, orbit=0.0730, rc=0.0003) val_acc=0.9927 val_f1=0.9928
# [Epoch 42] train_loss=0.0816 (act=0.0078, rot=0.0496, orbit=0.2879, rc=0.0063) train_acc=0.9978
#           val_loss=0.0361 (act=0.0225, rot=0.0000, orbit=0.0678, rc=0.0006) val_acc=0.9956 val_f1=0.9956
# [Epoch 43] train_loss=0.0824 (act=0.0097, rot=0.0453, orbit=0.2891, rc=0.0063) train_acc=0.9982
#           val_loss=0.1653 (act=0.1380, rot=0.0000, orbit=0.1329, rc=0.0036) val_acc=0.9713 val_f1=0.9714
# [Epoch 44] train_loss=0.0897 (act=0.0140, rot=0.0524, orbit=0.2914, rc=0.0083) train_acc=0.9970
#           val_loss=0.0531 (act=0.0381, rot=0.0000, orbit=0.0743, rc=0.0009) val_acc=0.9934 val_f1=0.9937
# [Epoch 45] train_loss=0.0818 (act=0.0091, rot=0.0443, orbit=0.2892, rc=0.0079) train_acc=0.9973
#           val_loss=0.0533 (act=0.0386, rot=0.0000, orbit=0.0723, rc=0.0010) val_acc=0.9930 val_f1=0.9930
# [Epoch 46] train_loss=0.0884 (act=0.0133, rot=0.0482, orbit=0.2929, rc=0.0104) train_acc=0.9967
#           val_loss=0.1020 (act=0.0800, rot=0.0000, orbit=0.1011, rc=0.0091) val_acc=0.9828 val_f1=0.9838
# [Epoch 47] train_loss=0.0783 (act=0.0067, rot=0.0433, orbit=0.2864, rc=0.0068) train_acc=0.9988
#           val_loss=0.0407 (act=0.0266, rot=0.0000, orbit=0.0692, rc=0.0016) val_acc=0.9954 val_f1=0.9951
# [Epoch 48] train_loss=0.0786 (act=0.0075, rot=0.0445, orbit=0.2836, rc=0.0053) train_acc=0.9983
#           val_loss=0.0420 (act=0.0269, rot=0.0000, orbit=0.0728, rc=0.0028) val_acc=0.9954 val_f1=0.9953
# [Epoch 49] train_loss=0.0798 (act=0.0087, rot=0.0405, orbit=0.2872, rc=0.0074) train_acc=0.9980
#           val_loss=0.0450 (act=0.0311, rot=0.0000, orbit=0.0681, rc=0.0011) val_acc=0.9942 val_f1=0.9942
# [Epoch 50] train_loss=0.0843 (act=0.0132, rot=0.0404, orbit=0.2869, rc=0.0080) train_acc=0.9973
#           val_loss=0.0935 (act=0.0735, rot=0.0000, orbit=0.0963, rc=0.0039) val_acc=0.9869 val_f1=0.9870
# [Epoch 51] train_loss=0.0735 (act=0.0043, rot=0.0390, orbit=0.2819, rc=0.0056) train_acc=0.9989
#           val_loss=0.0730 (act=0.0556, rot=0.0000, orbit=0.0834, rc=0.0037) val_acc=0.9896 val_f1=0.9898
# [Epoch 52] train_loss=0.0829 (act=0.0095, rot=0.0481, orbit=0.2870, rc=0.0078) train_acc=0.9983
#           val_loss=0.0478 (act=0.0329, rot=0.0000, orbit=0.0725, rc=0.0023) val_acc=0.9939 val_f1=0.9940
# [Epoch 53] train_loss=0.0815 (act=0.0078, rot=0.0526, orbit=0.2831, rc=0.0062) train_acc=0.9979
#           val_loss=0.0799 (act=0.0605, rot=0.0000, orbit=0.0943, rc=0.0027) val_acc=0.9871 val_f1=0.9875
# [Epoch 54] train_loss=0.0784 (act=0.0094, rot=0.0374, orbit=0.2844, rc=0.0048) train_acc=0.9984
#           val_loss=0.0642 (act=0.0469, rot=0.0000, orbit=0.0807, rc=0.0055) val_acc=0.9922 val_f1=0.9916
# [Epoch 55] train_loss=0.0778 (act=0.0088, rot=0.0385, orbit=0.2824, rc=0.0046) train_acc=0.9982
#           val_loss=0.0795 (act=0.0614, rot=0.0000, orbit=0.0876, rc=0.0028) val_acc=0.9898 val_f1=0.9899
# [Epoch 56] train_loss=0.0736 (act=0.0062, rot=0.0339, orbit=0.2809, rc=0.0052) train_acc=0.9988
#           val_loss=0.0497 (act=0.0345, rot=0.0000, orbit=0.0744, rc=0.0015) val_acc=0.9927 val_f1=0.9921
# [Epoch 57] train_loss=0.0824 (act=0.0119, rot=0.0419, orbit=0.2835, rc=0.0062) train_acc=0.9974
#           val_loss=0.0527 (act=0.0368, rot=0.0000, orbit=0.0780, rc=0.0018) val_acc=0.9932 val_f1=0.9932
# [Epoch 58] train_loss=0.0726 (act=0.0040, rot=0.0396, orbit=0.2790, rc=0.0047) train_acc=0.9992
#           val_loss=0.0500 (act=0.0361, rot=0.0000, orbit=0.0685, rc=0.0010) val_acc=0.9947 val_f1=0.9946
# [Epoch 59] train_loss=0.0821 (act=0.0135, rot=0.0311, orbit=0.2859, rc=0.0100) train_acc=0.9971
#           val_loss=0.0546 (act=0.0393, rot=0.0000, orbit=0.0754, rc=0.0011) val_acc=0.9939 val_f1=0.9935
# [Epoch 60] train_loss=0.0796 (act=0.0118, rot=0.0336, orbit=0.2813, rc=0.0073) train_acc=0.9980
#           val_loss=0.0699 (act=0.0525, rot=0.0000, orbit=0.0829, rc=0.0046) val_acc=0.9888 val_f1=0.9891
# [Epoch 61] train_loss=0.0732 (act=0.0057, rot=0.0315, orbit=0.2821, rc=0.0079) train_acc=0.9990
#           val_loss=0.0370 (act=0.0232, rot=0.0000, orbit=0.0678, rc=0.0013) val_acc=0.9956 val_f1=0.9953
# [Epoch 62] train_loss=0.0678 (act=0.0019, rot=0.0327, orbit=0.2768, rc=0.0034) train_acc=0.9993
#           val_loss=0.0608 (act=0.0442, rot=0.0000, orbit=0.0797, rc=0.0030) val_acc=0.9944 val_f1=0.9944
# [Epoch 63] train_loss=0.0678 (act=0.0026, rot=0.0309, orbit=0.2756, rc=0.0043) train_acc=0.9997
#           val_loss=0.0663 (act=0.0500, rot=0.0000, orbit=0.0806, rc=0.0012) val_acc=0.9910 val_f1=0.9908
# [Epoch 64] train_loss=0.0682 (act=0.0046, rot=0.0257, orbit=0.2762, rc=0.0031) train_acc=0.9991
#           val_loss=0.0582 (act=0.0428, rot=0.0000, orbit=0.0753, rc=0.0021) val_acc=0.9934 val_f1=0.9935
# [Epoch 65] train_loss=0.0720 (act=0.0087, rot=0.0215, orbit=0.2790, rc=0.0051) train_acc=0.9982
#           val_loss=0.0477 (act=0.0336, rot=0.0000, orbit=0.0691, rc=0.0014) val_acc=0.9942 val_f1=0.9937
# [Epoch 66] train_loss=0.0705 (act=0.0071, rot=0.0232, orbit=0.2784, rc=0.0040) train_acc=0.9986
#           val_loss=0.0813 (act=0.0614, rot=0.0000, orbit=0.0900, rc=0.0094) val_acc=0.9876 val_f1=0.9881
# [Epoch 67] train_loss=0.0685 (act=0.0028, rot=0.0319, orbit=0.2754, rc=0.0052) train_acc=0.9992
#           val_loss=0.0530 (act=0.0383, rot=0.0000, orbit=0.0719, rc=0.0014) val_acc=0.9939 val_f1=0.9937
# [Epoch 68] train_loss=0.0710 (act=0.0064, rot=0.0280, orbit=0.2774, rc=0.0034) train_acc=0.9986
#           val_loss=0.0605 (act=0.0449, rot=0.0000, orbit=0.0763, rc=0.0016) val_acc=0.9925 val_f1=0.9925
# [Epoch 69] train_loss=0.0711 (act=0.0091, rot=0.0193, orbit=0.2772, rc=0.0035) train_acc=0.9981
#           val_loss=0.0581 (act=0.0393, rot=0.0000, orbit=0.0846, rc=0.0094) val_acc=0.9922 val_f1=0.9923
# [Epoch 70] train_loss=0.0763 (act=0.0126, rot=0.0208, orbit=0.2810, rc=0.0066) train_acc=0.9971
#           val_loss=0.0838 (act=0.0675, rot=0.0000, orbit=0.0790, rc=0.0026) val_acc=0.9891 val_f1=0.9833
# [Epoch 71] train_loss=0.0685 (act=0.0035, rot=0.0265, orbit=0.2787, rc=0.0070) train_acc=0.9985
#           val_loss=0.0447 (act=0.0312, rot=0.0000, orbit=0.0666, rc=0.0007) val_acc=0.9954 val_f1=0.9955
# [Epoch 72] train_loss=0.0684 (act=0.0052, rot=0.0212, orbit=0.2778, rc=0.0064) train_acc=0.9988
#           val_loss=0.0543 (act=0.0398, rot=0.0000, orbit=0.0713, rc=0.0010) val_acc=0.9939 val_f1=0.9940
# [Epoch 73] train_loss=0.0625 (act=0.0013, rot=0.0195, orbit=0.2740, rc=0.0028) train_acc=0.9998
#           val_loss=0.0323 (act=0.0190, rot=0.0000, orbit=0.0647, rc=0.0020) val_acc=0.9968 val_f1=0.9965
#   ★ New best F1: 0.9965 - Model saved
# [Epoch 74] train_loss=0.0609 (act=0.0009, rot=0.0180, orbit=0.2710, rc=0.0021) train_acc=0.9999
#           val_loss=0.0474 (act=0.0342, rot=0.0000, orbit=0.0651, rc=0.0007) val_acc=0.9959 val_f1=0.9955
# [Epoch 75] train_loss=0.0662 (act=0.0049, rot=0.0171, orbit=0.2749, rc=0.0059) train_acc=0.9991
#           val_loss=0.0476 (act=0.0340, rot=0.0000, orbit=0.0670, rc=0.0011) val_acc=0.9947 val_f1=0.9944
# [Epoch 76] train_loss=0.0669 (act=0.0052, rot=0.0199, orbit=0.2745, rc=0.0043) train_acc=0.9993
#           val_loss=0.0392 (act=0.0265, rot=0.0000, orbit=0.0629, rc=0.0004) val_acc=0.9968 val_f1=0.9967
#   ★ New best F1: 0.9967 - Model saved
# [Epoch 77] train_loss=0.0666 (act=0.0050, rot=0.0185, orbit=0.2761, rc=0.0042) train_acc=0.9988
#           val_loss=0.0643 (act=0.0477, rot=0.0000, orbit=0.0804, rc=0.0029) val_acc=0.9917 val_f1=0.9919
# [Epoch 78] train_loss=0.0649 (act=0.0049, rot=0.0152, orbit=0.2737, rc=0.0035) train_acc=0.9992
#           val_loss=0.0381 (act=0.0258, rot=0.0000, orbit=0.0607, rc=0.0010) val_acc=0.9968 val_f1=0.9965
# [Epoch 79] train_loss=0.0647 (act=0.0035, rot=0.0201, orbit=0.2724, rc=0.0033) train_acc=0.9994
#           val_loss=0.0564 (act=0.0424, rot=0.0000, orbit=0.0684, rc=0.0013) val_acc=0.9937 val_f1=0.9937
# [Epoch 80] train_loss=0.0607 (act=0.0039, rot=0.0061, orbit=0.2717, rc=0.0035) train_acc=0.9992
#           val_loss=0.0445 (act=0.0310, rot=0.0000, orbit=0.0657, rc=0.0019) val_acc=0.9944 val_f1=0.9940
# [Epoch 81] train_loss=0.0576 (act=0.0004, rot=0.0096, orbit=0.2698, rc=0.0019) train_acc=1.0000
#           val_loss=0.0361 (act=0.0234, rot=0.0000, orbit=0.0615, rc=0.0020) val_acc=0.9964 val_f1=0.9959
# [Epoch 82] train_loss=0.0594 (act=0.0032, rot=0.0037, orbit=0.2712, rc=0.0041) train_acc=0.9993
#           val_loss=0.0620 (act=0.0476, rot=0.0000, orbit=0.0697, rc=0.0024) val_acc=0.9932 val_f1=0.9931
# [Epoch 83] train_loss=0.0623 (act=0.0044, rot=0.0089, orbit=0.2715, rc=0.0050) train_acc=0.9991
#           val_loss=0.1369 (act=0.1159, rot=0.0000, orbit=0.0975, rc=0.0073) val_acc=0.9849 val_f1=0.9848
# [Epoch 84] train_loss=0.0661 (act=0.0037, rot=0.0241, orbit=0.2726, rc=0.0034) train_acc=0.9993
#           val_loss=0.0429 (act=0.0293, rot=0.0000, orbit=0.0672, rc=0.0013) val_acc=0.9956 val_f1=0.9956
# [Epoch 85] train_loss=0.0591 (act=0.0008, rot=0.0127, orbit=0.2697, rc=0.0028) train_acc=0.9998
#           val_loss=0.0434 (act=0.0304, rot=0.0000, orbit=0.0633, rc=0.0015) val_acc=0.9964 val_f1=0.9960
# [Epoch 86] train_loss=0.0633 (act=0.0030, rot=0.0176, orbit=0.2709, rc=0.0043) train_acc=0.9995
#           val_loss=0.0591 (act=0.0446, rot=0.0000, orbit=0.0702, rc=0.0021) val_acc=0.9932 val_f1=0.9930
# [Epoch 87] train_loss=0.0608 (act=0.0012, rot=0.0156, orbit=0.2706, rc=0.0036) train_acc=0.9997
#           val_loss=0.0798 (act=0.0642, rot=0.0000, orbit=0.0755, rc=0.0024) val_acc=0.9922 val_f1=0.9921
# [Epoch 88] train_loss=0.0601 (act=0.0025, rot=0.0092, orbit=0.2710, rc=0.0036) train_acc=0.9996
#           val_loss=0.0632 (act=0.0492, rot=0.0000, orbit=0.0693, rc=0.0003) val_acc=0.9947 val_f1=0.9944
# [Epoch 89] train_loss=0.0656 (act=0.0065, rot=0.0123, orbit=0.2716, rc=0.0054) train_acc=0.9989
#           val_loss=0.0847 (act=0.0675, rot=0.0000, orbit=0.0812, rc=0.0046) val_acc=0.9903 val_f1=0.9902
# [Epoch 90] train_loss=0.0618 (act=0.0053, rot=0.0049, orbit=0.2709, rc=0.0045) train_acc=0.9991
#           val_loss=0.0578 (act=0.0438, rot=0.0000, orbit=0.0692, rc=0.0008) val_acc=0.9942 val_f1=0.9939
# [Epoch 91] train_loss=0.0632 (act=0.0062, rot=0.0059, orbit=0.2723, rc=0.0037) train_acc=0.9984
#           val_loss=0.0648 (act=0.0499, rot=0.0000, orbit=0.0708, rc=0.0036) val_acc=0.9932 val_f1=0.9928
# [Epoch 92] train_loss=0.0621 (act=0.0034, rot=0.0110, orbit=0.2722, rc=0.0049) train_acc=0.9994
#           val_loss=0.0812 (act=0.0638, rot=0.0000, orbit=0.0803, rc=0.0066) val_acc=0.9917 val_f1=0.9914
# [Epoch 93] train_loss=0.0631 (act=0.0047, rot=0.0110, orbit=0.2719, rc=0.0033) train_acc=0.9986
#           val_loss=0.0410 (act=0.0281, rot=0.0000, orbit=0.0634, rc=0.0012) val_acc=0.9951 val_f1=0.9947
# [Epoch 94] train_loss=0.0593 (act=0.0021, rot=0.0084, orbit=0.2708, rc=0.0028) train_acc=0.9992
#           val_loss=0.0456 (act=0.0317, rot=0.0000, orbit=0.0673, rc=0.0019) val_acc=0.9947 val_f1=0.9944
# [Epoch 95] train_loss=0.0617 (act=0.0045, rot=0.0071, orbit=0.2710, rc=0.0042) train_acc=0.9989
#           val_loss=0.0632 (act=0.0486, rot=0.0000, orbit=0.0718, rc=0.0010) val_acc=0.9942 val_f1=0.9939
# [Epoch 96] train_loss=0.0599 (act=0.0016, rot=0.0131, orbit=0.2690, rc=0.0031) train_acc=0.9997
#           val_loss=0.0694 (act=0.0524, rot=0.0000, orbit=0.0799, rc=0.0047) val_acc=0.9917 val_f1=0.9916
# [Epoch 97] train_loss=0.0603 (act=0.0024, rot=0.0120, orbit=0.2686, rc=0.0025) train_acc=0.9995
#           val_loss=0.0435 (act=0.0304, rot=0.0000, orbit=0.0638, rc=0.0017) val_acc=0.9951 val_f1=0.9949
# [Epoch 98] train_loss=0.0594 (act=0.0013, rot=0.0111, orbit=0.2699, rc=0.0040) train_acc=0.9995
#           val_loss=0.0415 (act=0.0288, rot=0.0000, orbit=0.0625, rc=0.0007) val_acc=0.9966 val_f1=0.9967
# [Epoch 99] train_loss=0.0561 (act=0.0002, rot=0.0073, orbit=0.2672, rc=0.0011) train_acc=1.0000
#           val_loss=0.0437 (act=0.0310, rot=0.0000, orbit=0.0634, rc=0.0004) val_acc=0.9959 val_f1=0.9954
# [Epoch 100] train_loss=0.0565 (act=0.0003, rot=0.0087, orbit=0.2663, rc=0.0014) train_acc=0.9999
#           val_loss=0.0556 (act=0.0417, rot=0.0000, orbit=0.0686, rc=0.0008) val_acc=0.9944 val_f1=0.9940
# [Epoch 101] train_loss=0.0635 (act=0.0057, rot=0.0110, orbit=0.2692, rc=0.0034) train_acc=0.9992
#           val_loss=0.0461 (act=0.0333, rot=0.0000, orbit=0.0630, rc=0.0012) val_acc=0.9968 val_f1=0.9970
#   ★ New best F1: 0.9970 - Model saved
# [Epoch 102] train_loss=0.0584 (act=0.0023, rot=0.0073, orbit=0.2676, rc=0.0019) train_acc=0.9996
#           val_loss=0.0819 (act=0.0660, rot=0.0000, orbit=0.0783, rc=0.0012) val_acc=0.9910 val_f1=0.9909
# [Epoch 103] train_loss=0.0567 (act=0.0013, rot=0.0054, orbit=0.2669, rc=0.0019) train_acc=0.9998
#           val_loss=0.0543 (act=0.0405, rot=0.0000, orbit=0.0672, rc=0.0019) val_acc=0.9951 val_f1=0.9949
# [Epoch 104] train_loss=0.0628 (act=0.0068, rot=0.0047, orbit=0.2689, rc=0.0042) train_acc=0.9992
#           val_loss=0.0461 (act=0.0320, rot=0.0000, orbit=0.0675, rc=0.0025) val_acc=0.9956 val_f1=0.9953
# [Epoch 105] train_loss=0.0585 (act=0.0015, rot=0.0111, orbit=0.2667, rc=0.0017) train_acc=0.9998
#           val_loss=0.0476 (act=0.0345, rot=0.0000, orbit=0.0648, rc=0.0008) val_acc=0.9949 val_f1=0.9944
# [Epoch 106] train_loss=0.0579 (act=0.0021, rot=0.0068, orbit=0.2672, rc=0.0016) train_acc=0.9997
#           val_loss=0.0514 (act=0.0374, rot=0.0000, orbit=0.0689, rc=0.0012) val_acc=0.9939 val_f1=0.9940
# [Epoch 107] train_loss=0.0556 (act=0.0009, rot=0.0038, orbit=0.2663, rc=0.0015) train_acc=0.9999
#           val_loss=0.0471 (act=0.0343, rot=0.0000, orbit=0.0637, rc=0.0004) val_acc=0.9956 val_f1=0.9957
# [Epoch 108] train_loss=0.0588 (act=0.0035, rot=0.0042, orbit=0.2678, rc=0.0024) train_acc=0.9995
#           val_loss=0.1032 (act=0.0854, rot=0.0000, orbit=0.0848, rc=0.0041) val_acc=0.9891 val_f1=0.9895
# [Epoch 109] train_loss=0.0601 (act=0.0038, rot=0.0081, orbit=0.2680, rc=0.0016) train_acc=0.9994
#           val_loss=0.0568 (act=0.0432, rot=0.0000, orbit=0.0674, rc=0.0010) val_acc=0.9942 val_f1=0.9937
# [Epoch 110] train_loss=0.0574 (act=0.0020, rot=0.0052, orbit=0.2668, rc=0.0024) train_acc=0.9996
#           val_loss=0.0498 (act=0.0360, rot=0.0000, orbit=0.0653, rc=0.0036) val_acc=0.9951 val_f1=0.9949
# [Epoch 111] train_loss=0.0584 (act=0.0034, rot=0.0038, orbit=0.2668, rc=0.0021) train_acc=0.9994
#           val_loss=0.0490 (act=0.0362, rot=0.0000, orbit=0.0626, rc=0.0015) val_acc=0.9959 val_f1=0.9960
# [Epoch 112] train_loss=0.0560 (act=0.0019, rot=0.0019, orbit=0.2664, rc=0.0016) train_acc=0.9997
#           val_loss=0.1127 (act=0.0941, rot=0.0000, orbit=0.0901, rc=0.0030) val_acc=0.9835 val_f1=0.9841
# [Epoch 113] train_loss=0.0628 (act=0.0054, rot=0.0095, orbit=0.2681, rc=0.0043) train_acc=0.9992
#           val_loss=0.0457 (act=0.0325, rot=0.0000, orbit=0.0647, rc=0.0011) val_acc=0.9954 val_f1=0.9955
# [Epoch 114] train_loss=0.0593 (act=0.0035, rot=0.0057, orbit=0.2675, rc=0.0027) train_acc=0.9996
#           val_loss=0.0483 (act=0.0351, rot=0.0000, orbit=0.0638, rc=0.0022) val_acc=0.9944 val_f1=0.9944
# [Epoch 115] train_loss=0.0568 (act=0.0012, rot=0.0076, orbit=0.2652, rc=0.0015) train_acc=0.9998
#           val_loss=0.0321 (act=0.0202, rot=0.0000, orbit=0.0587, rc=0.0008) val_acc=0.9966 val_f1=0.9963
# [Epoch 116] train_loss=0.0603 (act=0.0049, rot=0.0059, orbit=0.2661, rc=0.0017) train_acc=0.9994
#           val_loss=0.0567 (act=0.0413, rot=0.0000, orbit=0.0692, rc=0.0076) val_acc=0.9939 val_f1=0.9940
# [Epoch 117] train_loss=0.0598 (act=0.0023, rot=0.0127, orbit=0.2651, rc=0.0032) train_acc=0.9995
#           val_loss=0.0629 (act=0.0489, rot=0.0000, orbit=0.0681, rc=0.0017) val_acc=0.9939 val_f1=0.9938
# [Epoch 118] train_loss=0.0578 (act=0.0010, rot=0.0116, orbit=0.2652, rc=0.0013) train_acc=0.9998
#           val_loss=0.0335 (act=0.0218, rot=0.0000, orbit=0.0581, rc=0.0006) val_acc=0.9971 val_f1=0.9970
# [Epoch 119] train_loss=0.0574 (act=0.0026, rot=0.0044, orbit=0.2652, rc=0.0018) train_acc=0.9998
#           val_loss=0.0623 (act=0.0481, rot=0.0000, orbit=0.0700, rc=0.0010) val_acc=0.9934 val_f1=0.9932
# [Epoch 120] train_loss=0.0580 (act=0.0026, rot=0.0065, orbit=0.2658, rc=0.0014) train_acc=0.9997
#           val_loss=0.0428 (act=0.0303, rot=0.0000, orbit=0.0618, rc=0.0009) val_acc=0.9964 val_f1=0.9963
# [Epoch 121] train_loss=0.0577 (act=0.0030, rot=0.0042, orbit=0.2652, rc=0.0019) train_acc=0.9997
#           val_loss=0.0379 (act=0.0243, rot=0.0000, orbit=0.0650, rc=0.0031) val_acc=0.9964 val_f1=0.9965
# [Epoch 122] train_loss=0.0571 (act=0.0010, rot=0.0092, orbit=0.2649, rc=0.0018) train_acc=0.9997
#           val_loss=0.0409 (act=0.0282, rot=0.0000, orbit=0.0620, rc=0.0014) val_acc=0.9964 val_f1=0.9960
# [Epoch 123] train_loss=0.0585 (act=0.0041, rot=0.0023, orbit=0.2657, rc=0.0029) train_acc=0.9994
#           val_loss=0.0459 (act=0.0324, rot=0.0000, orbit=0.0657, rc=0.0017) val_acc=0.9959 val_f1=0.9956
# [Epoch 124] train_loss=0.0582 (act=0.0037, rot=0.0041, orbit=0.2652, rc=0.0013) train_acc=0.9994
#           val_loss=0.0753 (act=0.0592, rot=0.0000, orbit=0.0775, rc=0.0026) val_acc=0.9913 val_f1=0.9909
# [Epoch 125] train_loss=0.0575 (act=0.0024, rot=0.0059, orbit=0.2649, rc=0.0015) train_acc=0.9997
#           val_loss=0.0455 (act=0.0327, rot=0.0000, orbit=0.0637, rc=0.0005) val_acc=0.9964 val_f1=0.9961
# [Epoch 126] train_loss=0.0548 (act=0.0008, rot=0.0031, orbit=0.2639, rc=0.0016) train_acc=0.9998
#           val_loss=0.0377 (act=0.0258, rot=0.0000, orbit=0.0587, rc=0.0009) val_acc=0.9964 val_f1=0.9961
# [Epoch 127] train_loss=0.0558 (act=0.0020, rot=0.0018, orbit=0.2645, rc=0.0020) train_acc=0.9995
#           val_loss=0.0527 (act=0.0399, rot=0.0000, orbit=0.0631, rc=0.0006) val_acc=0.9956 val_f1=0.9953
# [Epoch 128] train_loss=0.0573 (act=0.0013, rot=0.0091, orbit=0.2641, rc=0.0022) train_acc=0.9996
#           val_loss=0.0461 (act=0.0333, rot=0.0000, orbit=0.0627, rc=0.0017) val_acc=0.9947 val_f1=0.9947
# [Epoch 129] train_loss=0.0547 (act=0.0004, rot=0.0045, orbit=0.2633, rc=0.0015) train_acc=0.9998
#           val_loss=0.0425 (act=0.0306, rot=0.0000, orbit=0.0591, rc=0.0005) val_acc=0.9964 val_f1=0.9962
# [Epoch 130] train_loss=0.0549 (act=0.0009, rot=0.0039, orbit=0.2635, rc=0.0010) train_acc=0.9999
#           val_loss=0.0438 (act=0.0306, rot=0.0000, orbit=0.0639, rc=0.0021) val_acc=0.9959 val_f1=0.9958
# [Epoch 131] train_loss=0.0542 (act=0.0003, rot=0.0030, orbit=0.2635, rc=0.0015) train_acc=0.9999
#           val_loss=0.0342 (act=0.0222, rot=0.0000, orbit=0.0578, rc=0.0020) val_acc=0.9968 val_f1=0.9965
# [Epoch 132] train_loss=0.0547 (act=0.0001, rot=0.0056, orbit=0.2632, rc=0.0009) train_acc=1.0000
#           val_loss=0.0511 (act=0.0383, rot=0.0000, orbit=0.0631, rc=0.0011) val_acc=0.9951 val_f1=0.9949
# [Epoch 133] train_loss=0.0578 (act=0.0029, rot=0.0061, orbit=0.2642, rc=0.0012) train_acc=0.9994
#           val_loss=0.0438 (act=0.0312, rot=0.0000, orbit=0.0623, rc=0.0009) val_acc=0.9968 val_f1=0.9969
# [Epoch 134] train_loss=0.0538 (act=0.0001, rot=0.0029, orbit=0.2631, rc=0.0010) train_acc=1.0000
#           val_loss=0.0351 (act=0.0235, rot=0.0000, orbit=0.0579, rc=0.0003) val_acc=0.9968 val_f1=0.9969
# [Epoch 135] train_loss=0.0568 (act=0.0018, rot=0.0075, orbit=0.2627, rc=0.0009) train_acc=0.9998
#           val_loss=0.0517 (act=0.0382, rot=0.0000, orbit=0.0662, rc=0.0013) val_acc=0.9949 val_f1=0.9951
# [Epoch 136] train_loss=0.0554 (act=0.0018, rot=0.0026, orbit=0.2631, rc=0.0011) train_acc=0.9998
#           val_loss=0.0483 (act=0.0354, rot=0.0000, orbit=0.0637, rc=0.0004) val_acc=0.9951 val_f1=0.9949
# [Epoch 137] train_loss=0.0574 (act=0.0017, rot=0.0096, orbit=0.2631, rc=0.0014) train_acc=0.9997
#           val_loss=0.0325 (act=0.0210, rot=0.0000, orbit=0.0569, rc=0.0007) val_acc=0.9973 val_f1=0.9974
#   ★ New best F1: 0.9974 - Model saved
# [Epoch 138] train_loss=0.0535 (act=0.0004, rot=0.0017, orbit=0.2620, rc=0.0010) train_acc=0.9999
#           val_loss=0.0398 (act=0.0280, rot=0.0000, orbit=0.0588, rc=0.0003) val_acc=0.9961 val_f1=0.9958
# [Epoch 139] train_loss=0.0542 (act=0.0002, rot=0.0037, orbit=0.2628, rc=0.0013) train_acc=0.9999
#           val_loss=0.0445 (act=0.0323, rot=0.0000, orbit=0.0610, rc=0.0003) val_acc=0.9961 val_f1=0.9958
# [Epoch 140] train_loss=0.0557 (act=0.0013, rot=0.0054, orbit=0.2623, rc=0.0013) train_acc=0.9999
#           val_loss=0.0416 (act=0.0282, rot=0.0000, orbit=0.0647, rc=0.0026) val_acc=0.9973 val_f1=0.9968
# [Epoch 141] train_loss=0.0588 (act=0.0045, rot=0.0048, orbit=0.2629, rc=0.0016) train_acc=0.9994
#           val_loss=0.0810 (act=0.0648, rot=0.0000, orbit=0.0770, rc=0.0042) val_acc=0.9900 val_f1=0.9903
# [Epoch 142] train_loss=0.0560 (act=0.0019, rot=0.0039, orbit=0.2627, rc=0.0018) train_acc=0.9996
#           val_loss=0.0528 (act=0.0394, rot=0.0000, orbit=0.0660, rc=0.0012) val_acc=0.9959 val_f1=0.9958
# [Epoch 143] train_loss=0.0546 (act=0.0007, rot=0.0035, orbit=0.2631, rc=0.0015) train_acc=0.9998
#           val_loss=0.0340 (act=0.0225, rot=0.0000, orbit=0.0571, rc=0.0006) val_acc=0.9971 val_f1=0.9968
# [Epoch 144] train_loss=0.0535 (act=0.0002, rot=0.0025, orbit=0.2618, rc=0.0008) train_acc=0.9999
#           val_loss=0.0452 (act=0.0329, rot=0.0000, orbit=0.0609, rc=0.0005) val_acc=0.9961 val_f1=0.9961
# [Epoch 145] train_loss=0.0561 (act=0.0029, rot=0.0011, orbit=0.2628, rc=0.0016) train_acc=0.9997
#           val_loss=0.0543 (act=0.0413, rot=0.0000, orbit=0.0638, rc=0.0015) val_acc=0.9944 val_f1=0.9943
# [Epoch 146] train_loss=0.0544 (act=0.0004, rot=0.0037, orbit=0.2622, rc=0.0018) train_acc=0.9998
#           val_loss=0.0674 (act=0.0535, rot=0.0000, orbit=0.0688, rc=0.0005) val_acc=0.9930 val_f1=0.9930
# [Epoch 147] train_loss=0.0538 (act=0.0005, rot=0.0026, orbit=0.2618, rc=0.0011) train_acc=0.9999
#           val_loss=0.0558 (act=0.0426, rot=0.0000, orbit=0.0653, rc=0.0008) val_acc=0.9944 val_f1=0.9944
# [Epoch 148] train_loss=0.0547 (act=0.0002, rot=0.0062, orbit=0.2621, rc=0.0011) train_acc=0.9999
#           val_loss=0.0297 (act=0.0186, rot=0.0000, orbit=0.0551, rc=0.0004) val_acc=0.9978 val_f1=0.9979
#   ★ New best F1: 0.9979 - Model saved
# [Epoch 149] train_loss=0.0536 (act=0.0003, rot=0.0020, orbit=0.2621, rc=0.0012) train_acc=0.9999
#           val_loss=0.0443 (act=0.0318, rot=0.0000, orbit=0.0612, rc=0.0017) val_acc=0.9959 val_f1=0.9956
# [Epoch 150] train_loss=0.0546 (act=0.0008, rot=0.0037, orbit=0.2625, rc=0.0010) train_acc=0.9998
#           val_loss=0.0550 (act=0.0420, rot=0.0000, orbit=0.0646, rc=0.0004) val_acc=0.9951 val_f1=0.9951
# [Epoch 151] train_loss=0.0529 (act=0.0001, rot=0.0012, orbit=0.2616, rc=0.0007) train_acc=1.0000
#           val_loss=0.0349 (act=0.0235, rot=0.0000, orbit=0.0566, rc=0.0004) val_acc=0.9971 val_f1=0.9972
# [Epoch 152] train_loss=0.0545 (act=0.0007, rot=0.0042, orbit=0.2614, rc=0.0013) train_acc=0.9998
#           val_loss=0.0834 (act=0.0689, rot=0.0000, orbit=0.0715, rc=0.0013) val_acc=0.9927 val_f1=0.9928
# [Epoch 153] train_loss=0.0549 (act=0.0001, rot=0.0070, orbit=0.2623, rc=0.0013) train_acc=1.0000
#           val_loss=0.0544 (act=0.0409, rot=0.0000, orbit=0.0659, rc=0.0013) val_acc=0.9959 val_f1=0.9956
# [Epoch 154] train_loss=0.0540 (act=0.0006, rot=0.0031, orbit=0.2618, rc=0.0006) train_acc=0.9999
#           val_loss=0.0609 (act=0.0471, rot=0.0000, orbit=0.0682, rc=0.0007) val_acc=0.9939 val_f1=0.9939
# [Epoch 155] train_loss=0.0559 (act=0.0025, rot=0.0024, orbit=0.2620, rc=0.0011) train_acc=0.9998
#           val_loss=0.0439 (act=0.0315, rot=0.0000, orbit=0.0609, rc=0.0007) val_acc=0.9956 val_f1=0.9954
# [Epoch 156] train_loss=0.0529 (act=0.0003, rot=0.0008, orbit=0.2612, rc=0.0007) train_acc=0.9999
#           val_loss=0.0412 (act=0.0292, rot=0.0000, orbit=0.0598, rc=0.0003) val_acc=0.9964 val_f1=0.9961
# [Epoch 157] train_loss=0.0541 (act=0.0010, rot=0.0020, orbit=0.2614, rc=0.0009) train_acc=0.9998
#           val_loss=0.0495 (act=0.0368, rot=0.0000, orbit=0.0616, rc=0.0017) val_acc=0.9947 val_f1=0.9947
# [Epoch 158] train_loss=0.0531 (act=0.0001, rot=0.0023, orbit=0.2613, rc=0.0007) train_acc=1.0000
#           val_loss=0.0474 (act=0.0342, rot=0.0000, orbit=0.0649, rc=0.0012) val_acc=0.9951 val_f1=0.9949
# [Epoch 159] train_loss=0.0544 (act=0.0014, rot=0.0016, orbit=0.2617, rc=0.0010) train_acc=0.9998
#           val_loss=0.0509 (act=0.0380, rot=0.0000, orbit=0.0641, rc=0.0004) val_acc=0.9951 val_f1=0.9951
# [Epoch 160] train_loss=0.0586 (act=0.0044, rot=0.0051, orbit=0.2620, rc=0.0012) train_acc=0.9995
#           val_loss=0.1008 (act=0.0844, rot=0.0000, orbit=0.0811, rc=0.0012) val_acc=0.9891 val_f1=0.9890
# [Epoch 161] train_loss=0.0539 (act=0.0009, rot=0.0016, orbit=0.2616, rc=0.0009) train_acc=0.9998
#           val_loss=0.0316 (act=0.0204, rot=0.0000, orbit=0.0555, rc=0.0008) val_acc=0.9976 val_f1=0.9974
# [Epoch 162] train_loss=0.0538 (act=0.0008, rot=0.0023, orbit=0.2612, rc=0.0008) train_acc=0.9998
#           val_loss=0.0763 (act=0.0620, rot=0.0000, orbit=0.0691, rc=0.0022) val_acc=0.9932 val_f1=0.9933
# [Epoch 163] train_loss=0.0546 (act=0.0016, rot=0.0014, orbit=0.2614, rc=0.0012) train_acc=0.9998
#           val_loss=0.0447 (act=0.0323, rot=0.0000, orbit=0.0612, rc=0.0008) val_acc=0.9959 val_f1=0.9956
# [Epoch 164] train_loss=0.0528 (act=0.0001, rot=0.0012, orbit=0.2610, rc=0.0007) train_acc=1.0000
#           val_loss=0.0455 (act=0.0333, rot=0.0000, orbit=0.0602, rc=0.0008) val_acc=0.9956 val_f1=0.9956
# [Epoch 165] train_loss=0.0530 (act=0.0001, rot=0.0021, orbit=0.2608, rc=0.0005) train_acc=1.0000
#           val_loss=0.0537 (act=0.0408, rot=0.0000, orbit=0.0636, rc=0.0009) val_acc=0.9937 val_f1=0.9935
# [Epoch 166] train_loss=0.0528 (act=0.0001, rot=0.0017, orbit=0.2610, rc=0.0004) train_acc=1.0000
#           val_loss=0.0478 (act=0.0356, rot=0.0000, orbit=0.0603, rc=0.0004) val_acc=0.9944 val_f1=0.9944
# [Epoch 167] train_loss=0.0538 (act=0.0009, rot=0.0017, orbit=0.2612, rc=0.0008) train_acc=0.9998
#           val_loss=0.0526 (act=0.0388, rot=0.0000, orbit=0.0669, rc=0.0017) val_acc=0.9947 val_f1=0.9946
# [Epoch 168] train_loss=0.0527 (act=0.0001, rot=0.0014, orbit=0.2607, rc=0.0006) train_acc=1.0000
#           val_loss=0.0463 (act=0.0343, rot=0.0000, orbit=0.0595, rc=0.0001) val_acc=0.9961 val_f1=0.9958
# [Epoch 169] train_loss=0.0531 (act=0.0001, rot=0.0026, orbit=0.2605, rc=0.0007) train_acc=1.0000
#           val_loss=0.0349 (act=0.0232, rot=0.0000, orbit=0.0577, rc=0.0007) val_acc=0.9964 val_f1=0.9960
# [Epoch 170] train_loss=0.0534 (act=0.0003, rot=0.0021, orbit=0.2610, rc=0.0015) train_acc=0.9998
#           val_loss=0.0381 (act=0.0260, rot=0.0000, orbit=0.0604, rc=0.0003) val_acc=0.9973 val_f1=0.9972
# [Epoch 171] train_loss=0.0528 (act=0.0001, rot=0.0013, orbit=0.2610, rc=0.0006) train_acc=1.0000
#           val_loss=0.0411 (act=0.0290, rot=0.0000, orbit=0.0591, rc=0.0013) val_acc=0.9961 val_f1=0.9960
# [Epoch 172] train_loss=0.0528 (act=0.0002, rot=0.0013, orbit=0.2605, rc=0.0006) train_acc=0.9999
#           val_loss=0.0594 (act=0.0462, rot=0.0000, orbit=0.0643, rc=0.0015) val_acc=0.9947 val_f1=0.9947
# [Epoch 173] train_loss=0.0534 (act=0.0004, rot=0.0021, orbit=0.2608, rc=0.0009) train_acc=0.9999
#           val_loss=0.0316 (act=0.0197, rot=0.0000, orbit=0.0582, rc=0.0009) val_acc=0.9971 val_f1=0.9970
# [Epoch 174] train_loss=0.0527 (act=0.0001, rot=0.0014, orbit=0.2605, rc=0.0006) train_acc=1.0000
#           val_loss=0.0446 (act=0.0325, rot=0.0000, orbit=0.0600, rc=0.0002) val_acc=0.9964 val_f1=0.9962
# [Epoch 175] train_loss=0.0568 (act=0.0026, rot=0.0063, orbit=0.2612, rc=0.0007) train_acc=0.9996
#           val_loss=0.0569 (act=0.0439, rot=0.0000, orbit=0.0644, rc=0.0005) val_acc=0.9944 val_f1=0.9945
# [Epoch 176] train_loss=0.0559 (act=0.0028, rot=0.0019, orbit=0.2612, rc=0.0014) train_acc=0.9997
#           val_loss=0.0737 (act=0.0597, rot=0.0000, orbit=0.0693, rc=0.0006) val_acc=0.9937 val_f1=0.9936
# [Epoch 177] train_loss=0.0526 (act=0.0000, rot=0.0011, orbit=0.2603, rc=0.0005) train_acc=1.0000
#           val_loss=0.0396 (act=0.0279, rot=0.0000, orbit=0.0587, rc=0.0001) val_acc=0.9971 val_f1=0.9967
# [Epoch 178] train_loss=0.0525 (act=0.0000, rot=0.0011, orbit=0.2602, rc=0.0004) train_acc=1.0000
#           val_loss=0.0468 (act=0.0346, rot=0.0000, orbit=0.0610, rc=0.0004) val_acc=0.9956 val_f1=0.9955
# [Epoch 179] train_loss=0.0563 (act=0.0032, rot=0.0025, orbit=0.2608, rc=0.0010) train_acc=0.9998
#           val_loss=0.0858 (act=0.0706, rot=0.0000, orbit=0.0724, rc=0.0040) val_acc=0.9922 val_f1=0.9920
# [Epoch 180] train_loss=0.0526 (act=0.0001, rot=0.0010, orbit=0.2606, rc=0.0005) train_acc=1.0000
#           val_loss=0.0555 (act=0.0429, rot=0.0000, orbit=0.0627, rc=0.0003) val_acc=0.9949 val_f1=0.9948
# [Epoch 181] train_loss=0.0538 (act=0.0011, rot=0.0015, orbit=0.2606, rc=0.0007) train_acc=0.9998
#           val_loss=0.1093 (act=0.0928, rot=0.0000, orbit=0.0806, rc=0.0020) val_acc=0.9896 val_f1=0.9897
# [Epoch 182] train_loss=0.0533 (act=0.0002, rot=0.0028, orbit=0.2604, rc=0.0006) train_acc=0.9999
#           val_loss=0.0494 (act=0.0369, rot=0.0000, orbit=0.0622, rc=0.0004) val_acc=0.9954 val_f1=0.9951
# [Epoch 183] train_loss=0.0530 (act=0.0001, rot=0.0022, orbit=0.2602, rc=0.0008) train_acc=1.0000
#           val_loss=0.0338 (act=0.0220, rot=0.0000, orbit=0.0578, rc=0.0011) val_acc=0.9968 val_f1=0.9965
# [Epoch 184] train_loss=0.0525 (act=0.0001, rot=0.0007, orbit=0.2605, rc=0.0006) train_acc=1.0000
#           val_loss=0.0388 (act=0.0271, rot=0.0000, orbit=0.0579, rc=0.0006) val_acc=0.9964 val_f1=0.9962
# [Epoch 185] train_loss=0.0533 (act=0.0008, rot=0.0008, orbit=0.2608, rc=0.0006) train_acc=0.9998
#           val_loss=0.0486 (act=0.0355, rot=0.0000, orbit=0.0626, rc=0.0025) val_acc=0.9954 val_f1=0.9953
# [Epoch 186] train_loss=0.0533 (act=0.0003, rot=0.0025, orbit=0.2603, rc=0.0008) train_acc=0.9999
#           val_loss=0.0330 (act=0.0214, rot=0.0000, orbit=0.0571, rc=0.0005) val_acc=0.9968 val_f1=0.9967
# [Epoch 187] train_loss=0.0565 (act=0.0038, rot=0.0012, orbit=0.2611, rc=0.0006) train_acc=0.9997
#           val_loss=0.0471 (act=0.0348, rot=0.0000, orbit=0.0611, rc=0.0003) val_acc=0.9959 val_f1=0.9958
# [Epoch 188] train_loss=0.0532 (act=0.0002, rot=0.0028, orbit=0.2605, rc=0.0007) train_acc=0.9999
#           val_loss=0.0574 (act=0.0443, rot=0.0000, orbit=0.0640, rc=0.0010) val_acc=0.9949 val_f1=0.9949
# [Epoch 189] train_loss=0.0544 (act=0.0001, rot=0.0072, orbit=0.2603, rc=0.0004) train_acc=1.0000
#           val_loss=0.0454 (act=0.0332, rot=0.0000, orbit=0.0601, rc=0.0009) val_acc=0.9956 val_f1=0.9953
# [Epoch 190] train_loss=0.0526 (act=0.0001, rot=0.0014, orbit=0.2603, rc=0.0005) train_acc=1.0000
#           val_loss=0.0344 (act=0.0232, rot=0.0000, orbit=0.0559, rc=0.0002) val_acc=0.9976 val_f1=0.9974
# [Epoch 191] train_loss=0.0534 (act=0.0005, rot=0.0021, orbit=0.2607, rc=0.0007) train_acc=0.9999
#           val_loss=0.0450 (act=0.0328, rot=0.0000, orbit=0.0597, rc=0.0013) val_acc=0.9959 val_f1=0.9958
# [Epoch 192] train_loss=0.0528 (act=0.0001, rot=0.0017, orbit=0.2604, rc=0.0008) train_acc=1.0000
#           val_loss=0.0514 (act=0.0376, rot=0.0000, orbit=0.0666, rc=0.0025) val_acc=0.9954 val_f1=0.9953
# [Epoch 193] train_loss=0.0526 (act=0.0001, rot=0.0017, orbit=0.2601, rc=0.0004) train_acc=1.0000
#           val_loss=0.0504 (act=0.0371, rot=0.0000, orbit=0.0623, rc=0.0040) val_acc=0.9964 val_f1=0.9963
# [Epoch 194] train_loss=0.0537 (act=0.0011, rot=0.0010, orbit=0.2609, rc=0.0007) train_acc=0.9998
#           val_loss=0.0406 (act=0.0282, rot=0.0000, orbit=0.0609, rc=0.0010) val_acc=0.9966 val_f1=0.9965
# [Epoch 195] train_loss=0.0548 (act=0.0018, rot=0.0018, orbit=0.2607, rc=0.0014) train_acc=0.9998
#           val_loss=0.0484 (act=0.0363, rot=0.0000, orbit=0.0607, rc=0.0001) val_acc=0.9954 val_f1=0.9951
# [Epoch 196] train_loss=0.0530 (act=0.0001, rot=0.0026, orbit=0.2604, rc=0.0003) train_acc=1.0000
#           val_loss=0.0339 (act=0.0224, rot=0.0000, orbit=0.0570, rc=0.0007) val_acc=0.9976 val_f1=0.9974
# [Epoch 197] train_loss=0.0524 (act=0.0000, rot=0.0006, orbit=0.2603, rc=0.0007) train_acc=1.0000
#           val_loss=0.0411 (act=0.0297, rot=0.0000, orbit=0.0571, rc=0.0003) val_acc=0.9966 val_f1=0.9963
# [Epoch 198] train_loss=0.0529 (act=0.0004, rot=0.0010, orbit=0.2602, rc=0.0007) train_acc=0.9999
#           val_loss=0.0500 (act=0.0372, rot=0.0000, orbit=0.0628, rc=0.0016) val_acc=0.9964 val_f1=0.9963
# Early stopping at epoch 198
# Training completed in 2670.09 seconds
# ##############################
# NO ROCO_TTA
# ##############################
# Final evaluation...
#
# === FINAL RESULTS ===
# Accuracy: 0.9978
# F1 Score: 0.9979
# Precision: 0.9979
# Recall: 0.9979
# Sensitivity: 0.9979
# Silhouette Score: 0.7781
# Training Time: 2670.09s
# Inference Time: 1.46s
#
# Class-wise F1 Scores:
# Standing still: 0.9973
# Sitting and relaxing: 1.0000
# Lying down: 0.9986
# Walking: 0.9973
# Climbing stairs: 0.9986
# Waist bends forward: 0.9941
# Frontal elevation of arms: 0.9972
# Knees bending (crouching): 0.9929
# Cycling: 0.9986
# Jogging: 1.0000
# Running: 1.0000
# Jump front & back: 1.0000
#
# Generating visualizations...
# Evaluation complete!
#
# ##############################
# ROCO_TTA
# ##############################
# Final evaluation...
#
# === FINAL RESULTS ===
# Accuracy: 0.9978
# F1 Score: 0.9979
# Precision: 0.9979
# Recall: 0.9979
# Sensitivity: 0.9979
# Silhouette Score: 0.7781
# Training Time: 2670.09s
# Inference Time: 72.60s
#
# Class-wise F1 Scores:
# Standing still: 0.9973
# Sitting and relaxing: 1.0000
# Lying down: 0.9986
# Walking: 0.9973
# Climbing stairs: 0.9986
# Waist bends forward: 0.9941
# Frontal elevation of arms: 0.9972
# Knees bending (crouching): 0.9929
# Cycling: 0.9986
# Jogging: 1.0000
# Running: 1.0000
# Jump front & back: 1.0000
#
# Generating visualizations...
# Evaluation complete!
